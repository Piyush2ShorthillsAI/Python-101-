# %%
# Variable assignment
a = 10
b = 20

# Function definition
def add_numbers(x, y):
    return x + y

# Loop
for i in range(5):
    print(f"Loop iteration {i}: {add_numbers(a, b)}")
# Out:
# Loop iteration 0: 30
# Loop iteration 1: 30
# Loop iteration 2: 30
# Loop iteration 3: 30
# Loop iteration 4: 30
